# %% [raw]
# Consider any text paragraph. Preprocess the text to remove any special
# characters and digits.

# %%
import re

# %%
text = """Python Programming 101 is fun! It helps you learn coding, data science,
and machine learning in 2025. Welcome to Python @ Academy."""
print("Original Text:")
print(text)

clean_text = re.sub('[^a-zA-Z ]', '', text)

print("\nText after removing special characters and digits:")
print(clean_text)
# Out:
# Original Text:
# Python Programming 101 is fun! It helps you learn coding, data science,
# and machine learning in 2025. Welcome to Python @ Academy.
#
# Text after removing special characters and digits:
# Python Programming  is fun It helps you learn coding data scienceand machine learning in  Welcome to Python  Academy
