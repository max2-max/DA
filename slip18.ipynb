# %%
import nltk
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.probability import FreqDist
from wordcloud import WordCloud

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/admin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/admin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = """Machine learning is a branch of artificial intelligence that allows
computers to learn from data.
It is widely used in recommendation systems, image recognition, and natural
language processing.
With the growth of data, machine learning has become an important technology
in many industries."""
print("Original Text:\n", text)

sentences = sent_tokenize(text)
print("\nSentences:")
print(sentences)

words = word_tokenize(text.lower())

stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if word.isalpha() and word not in
stop_words]
print("\nWords after removing stopwords:")
print(filtered_words)

freq_dist = FreqDist(filtered_words)
print("\nWord Frequency Distribution:")
print(freq_dist)

freq_dist.plot(10)
plt.title("Word Frequency Distribution")
plt.show()# Step 7: Generate WordCloud
wordcloud = WordCloud(width=800, height=400,
background_color='white').generate(" ".join(filtered_words))
plt.figure(figsize=(10,5))
plt.imshow(wordcloud)
plt.axis("off")
plt.title("WordCloud")
plt.show()
# Out:
# Original Text:
#  Machine learning is a branch of artificial intelligence that allows
# computers to learn from data.
# It is widely used in recommendation systems, image recognition, and natural
# language processing.
# With the growth of data, machine learning has become an important technology
# in many industries.
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[7], line 9
#       1 text = """Machine learning is a branch of artificial intelligence that allows
#       2 computers to learn from data.
#       3 It is widely used in recommendation systems, image recognition, and natural
#       4 language processing.
#       5 With the growth of data, machine learning has become an important technology
#       6 in many industries."""
#       7 print("Original Text:\n", text)
# ----> 9 sentences = sent_tokenize(text)
#      10 print("\nSentences:")
# ...
