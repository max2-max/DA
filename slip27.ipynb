# %% [raw]
# Create your own transactions dataset and apply the above process on your
# dataset.

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
transactions = [
['Milk','Bread','Butter'],
['Bread','Eggs'],
['Milk','Bread','Eggs','Butter'],
['Milk','Butter'],
['Bread','Butter','Eggs']
]
print("Transaction Dataset:")
for i, t in enumerate(transactions,1):
    print("TID", i, ":", t)

te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_array, columns=te.columns_)
print("\nDataset in Numeric Format:")
print(df)

frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)
print("\nFrequent Itemsets:")
print(frequent_itemsets)

rules = association_rules(frequent_itemsets, metric="confidence",
min_threshold=0.6)
print("\nAssociation Rules:")
print(rules)
# Out:
# Transaction Dataset:
# TID 1 : ['Milk', 'Bread', 'Butter']
# TID 2 : ['Bread', 'Eggs']
# TID 3 : ['Milk', 'Bread', 'Eggs', 'Butter']
# TID 4 : ['Milk', 'Butter']
# TID 5 : ['Bread', 'Butter', 'Eggs']
#
# Dataset in Numeric Format:
#    Bread  Butter   Eggs   Milk
# 0   True    True  False   True
# 1   True   False   True  False
# 2   True    True   True   True
# 3  False    True  False   True
# 4   True    True   True  False
#
# Frequent Itemsets:
#     support               itemsets
# 0       0.8                (Bread)
# 1       0.8               (Butter)
# 2       0.6                 (Eggs)
# 3       0.6                 (Milk)
# 4       0.6        (Bread, Butter)
# 5       0.6          (Bread, Eggs)
# 6       0.4          (Bread, Milk)
# 7       0.4         (Eggs, Butter)
# 8       0.6         (Milk, Butter)
# 9       0.4  (Bread, Eggs, Butter)
# 10      0.4  (Bread, Milk, Butter)
#
# Association Rules:
#         antecedents      consequents  antecedent support  consequent support  \
# 0           (Bread)         (Butter)                 0.8                 0.8
# 1          (Butter)          (Bread)                 0.8                 0.8
# 2           (Bread)           (Eggs)                 0.8                 0.6
# 3            (Eggs)          (Bread)                 0.6                 0.8
# 4            (Milk)          (Bread)                 0.6                 0.8
# 5            (Eggs)         (Butter)                 0.6                 0.8
# 6            (Milk)         (Butter)                 0.6                 0.8
# 7          (Butter)           (Milk)                 0.8                 0.6
# 8     (Bread, Eggs)         (Butter)                 0.6                 0.8
# 9   (Bread, Butter)           (Eggs)                 0.6                 0.6
# 10   (Eggs, Butter)          (Bread)                 0.4                 0.8
# 11           (Eggs)  (Bread, Butter)                 0.6                 0.6
# 12    (Bread, Milk)         (Butter)                 0.4                 0.8
# 13  (Bread, Butter)           (Milk)                 0.6                 0.6
# 14   (Milk, Butter)          (Bread)                 0.6                 0.8
# 15           (Milk)  (Bread, Butter)                 0.6                 0.6
#
#     support  confidence      lift  representativity  leverage  conviction  \
# 0       0.6    0.750000  0.937500               1.0     -0.04         0.8
# 1       0.6    0.750000  0.937500               1.0     -0.04         0.8
# 2       0.6    0.750000  1.250000               1.0      0.12         1.6
# 3       0.6    1.000000  1.250000               1.0      0.12         inf
# 4       0.4    0.666667  0.833333               1.0     -0.08         0.6
# 5       0.4    0.666667  0.833333               1.0     -0.08         0.6
# 6       0.6    1.000000  1.250000               1.0      0.12         inf
# 7       0.6    0.750000  1.250000               1.0      0.12         1.6
# 8       0.4    0.666667  0.833333               1.0     -0.08         0.6
# 9       0.4    0.666667  1.111111               1.0      0.04         1.2
# 10      0.4    1.000000  1.250000               1.0      0.08         inf
# 11      0.4    0.666667  1.111111               1.0      0.04         1.2
# 12      0.4    1.000000  1.250000               1.0      0.08         inf
# 13      0.4    0.666667  1.111111               1.0      0.04         1.2
# 14      0.4    0.666667  0.833333               1.0     -0.08         0.6
# 15      0.4    0.666667  1.111111               1.0      0.04         1.2
#
#     zhangs_metric  jaccard  certainty  kulczynski
# 0       -0.250000     0.60  -0.250000    0.750000
# 1       -0.250000     0.60  -0.250000    0.750000
# 2        1.000000     0.75   0.375000    0.875000
# 3        0.500000     0.75   1.000000    0.875000
# 4       -0.333333     0.40  -0.666667    0.583333
# 5       -0.333333     0.40  -0.666667    0.583333
# 6        0.500000     0.75   1.000000    0.875000
# 7        1.000000     0.75   0.375000    0.875000
# 8       -0.333333     0.40  -0.666667    0.583333
# 9        0.250000     0.50   0.166667    0.666667
# 10       0.333333     0.50   1.000000    0.750000
# 11       0.250000     0.50   0.166667    0.666667
# 12       0.333333     0.50   1.000000    0.750000
# 13       0.250000     0.50   0.166667    0.666667
# 14      -0.333333     0.40  -0.666667    0.583333
# 15       0.250000     0.50   0.166667    0.666667
