# %% [raw]
# Create the following dataset in python & Convert the categorical values into
# numeric format.Apply the apriori algorithm on the above dataset to generate
# the frequent itemsets and association rules. Repeat the process with different
# min_sup values.

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
transactions = [
['eggs','milk','bread'],
['eggs','apple'],
['milk','bread'],
['apple','milk'],
['milk','apple','bread']
]
print("Transactions Dataset:")
for i, t in enumerate(transactions,1):
    print("TID",i,":",t)

te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_array, columns=te.columns_)
print("\nDataset in Numeric Format:")
print(df)

frequent_itemsets1 = apriori(df, min_support=0.4, use_colnames=True)
print("\nFrequent Itemsets (min_support = 0.4):")
print(frequent_itemsets1)
rules1 = association_rules(frequent_itemsets1, metric="confidence",
min_threshold=0.5)
print("\nAssociation Rules (min_support = 0.4):")
print(rules1)

frequent_itemsets2 = apriori(df, min_support=0.6, use_colnames=True)
print("\nFrequent Itemsets (min_support = 0.6):")
print(frequent_itemsets2)
rules2 = association_rules(frequent_itemsets2, metric="confidence",
min_threshold=0.5)
print("\nAssociation Rules (min_support = 0.6):")
print(rules2)
# Out:
# Transactions Dataset:
# TID 1 : ['eggs', 'milk', 'bread']
# TID 2 : ['eggs', 'apple']
# TID 3 : ['milk', 'bread']
# TID 4 : ['apple', 'milk']
# TID 5 : ['milk', 'apple', 'bread']
#
# Dataset in Numeric Format:
#    apple  bread   eggs   milk
# 0  False   True   True   True
# 1   True  False   True  False
# 2  False   True  False   True
# 3   True  False  False   True
# 4   True   True  False   True
#
# Frequent Itemsets (min_support = 0.4):
#    support       itemsets
# 0      0.6        (apple)
# 1      0.6        (bread)
# 2      0.4         (eggs)
# 3      0.8         (milk)
# 4      0.4  (milk, apple)
# 5      0.6  (bread, milk)
#
# Association Rules (min_support = 0.4):
#   antecedents consequents  antecedent support  consequent support  support  \
# 0      (milk)     (apple)                 0.8                 0.6      0.4
# 1     (apple)      (milk)                 0.6                 0.8      0.4
# 2     (bread)      (milk)                 0.6                 0.8      0.6
# 3      (milk)     (bread)                 0.8                 0.6      0.6
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.500000  0.833333               1.0     -0.08         0.8
# 1    0.666667  0.833333               1.0     -0.08         0.6
# 2    1.000000  1.250000               1.0      0.12         inf
# 3    0.750000  1.250000               1.0      0.12         1.6
#
#    zhangs_metric  jaccard  certainty  kulczynski
# 0      -0.500000     0.40  -0.250000    0.583333
# 1      -0.333333     0.40  -0.666667    0.583333
# 2       0.500000     0.75   1.000000    0.875000
# 3       1.000000     0.75   0.375000    0.875000
#
# Frequent Itemsets (min_support = 0.6):
#    support       itemsets
# 0      0.6        (apple)
# 1      0.6        (bread)
# 2      0.8         (milk)
# 3      0.6  (bread, milk)
#
# Association Rules (min_support = 0.6):
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (bread)      (milk)                 0.6                 0.8      0.6
# 1      (milk)     (bread)                 0.8                 0.6      0.6
#
#    confidence  lift  representativity  leverage  conviction  zhangs_metric  \
# 0        1.00  1.25               1.0      0.12         inf            0.5
# 1        0.75  1.25               1.0      0.12         1.6            1.0
#
#    jaccard  certainty  kulczynski
# 0     0.75      1.000       0.875
# 1     0.75      0.375       0.875
